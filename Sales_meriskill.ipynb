# %% [markdown]
# <a href="https://colab.research.google.com/github/munga21407/data_analysis/blob/main/Sales_meriskill.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-54bc57f2-6403-48c6-953b-5e12143a8a63" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-54bc57f2-6403-48c6-953b-5e12143a8a63">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile

with zipfile.ZipFile('/content/Dataset MeriSKILL (1).zip', 'r') as zip_ref:
  zip_ref.extractall()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv('/content/Sales Data.csv')
print(data.head())
# Out:
#    Unnamed: 0  Order ID               Product  Quantity Ordered  Price Each  \
# 0           0    295665    Macbook Pro Laptop                 1     1700.00
# 1           1    295666    LG Washing Machine                 1      600.00
# 2           2    295667  USB-C Charging Cable                 1       11.95
# 3           3    295668      27in FHD Monitor                 1      149.99
# 4           4    295669  USB-C Charging Cable                 1       11.95
#
#             Order Date                        Purchase Address  Month  \
# 0  2019-12-30 00:01:00  136 Church St, New York City, NY 10001     12
# 1  2019-12-29 07:03:00     562 2nd St, New York City, NY 10001     12
# 2  2019-12-12 18:21:00    277 Main St, New York City, NY 10001     12
# 3  2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016     12
# 4  2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301     12
#
#      Sales            City  Hour
# 0  1700.00   New York City     0
# ...

# %%
sales_data['Sales'] = sales_data['Quantity Ordered'] * sales_data['Price Each']
total_sales = sales_data['Sales'].sum()
print(f"Total Sales: ${total_sales:.2f}")
# Out:
# Total Sales: $34492035.97

# %%
print(sales_data.head())
print(sales_data.isnull().sum())
sales_data['Order Date'] = pd.to_datetime(sales_data['Order Date'])
sales_data['Hour'] = sales_data['Order Date'].dt.hour
plt.figure(figsize=(12, 6))
sns.lineplot(x='Hour', y='Quantity Ordered', data=sales_data, estimator='sum')
plt.title('Sales Trends Over the Day')
plt.xlabel('Hour of the Day')
plt.ylabel('Quantity Ordered')
plt.show()
best_selling_products = sales_data.groupby('Product')['Quantity Ordered'].sum().sort_values(ascending=False).head(10)
print("Top 10 Best-Selling Products:")
print(best_selling_products)
sales_data['Sales'] = sales_data['Quantity Ordered'] * sales_data['Price Each']
total_sales = sales_data['Sales'].sum()
profit_margin = (sales_data['Sales'].sum() - sales_data['Sales'].sum()) / sales_data['Sales'].sum()
print(f"Total Sales: ${total_sales:.2f}")
print(f"Profit Margin: {profit_margin * 100:.2f}%")
#  a bar chart for top 10 best-selling products
plt.figure(figsize=(12, 6))
sns.barplot(x=best_selling_products.index, y=best_selling_products.values)
plt.title('Top 10 Best-Selling Products')
plt.xlabel('Product')
plt.ylabel('Quantity Ordered')
plt.xticks(rotation=45)
plt.show()
# sales by city
plt.figure(figsize=(12, 6))
sns.barplot(x='City', y='Sales', data=sales_data, estimator=sum)
plt.title('Total Sales by City')
plt.xlabel('City')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.show()
# Out:
#    Unnamed: 0  Order ID               Product  Quantity Ordered  Price Each  \
# 0           0    295665    Macbook Pro Laptop                 1     1700.00
# 1           1    295666    LG Washing Machine                 1      600.00
# 2           2    295667  USB-C Charging Cable                 1       11.95
# 3           3    295668      27in FHD Monitor                 1      149.99
# 4           4    295669  USB-C Charging Cable                 1       11.95
#
#            Order Date                        Purchase Address  Month    Sales  \
# 0 2019-12-30 00:01:00  136 Church St, New York City, NY 10001     12  1700.00
# 1 2019-12-29 07:03:00     562 2nd St, New York City, NY 10001     12   600.00
# 2 2019-12-12 18:21:00    277 Main St, New York City, NY 10001     12    11.95
# 3 2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016     12   149.99
# 4 2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301     12    11.95
#
#              City  Hour
# ...
